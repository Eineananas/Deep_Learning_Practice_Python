# %%
#https://www.jianshu.com/p/d0cb367752e8
#https://blog.csdn.net/sinat_26917383/article/details/83029140
#https://zhuanlan.zhihu.com/p/165975230
#https://blog.csdn.net/weixin_38235865/article/details/115578458

# %% [markdown]
# ### 加载词向量

# %%
from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

# %%
glove_file = datapath('D:/jupyter_file/textana/standford_nlp/glove.6B.100d.txt')
word2vec_glove_file = get_tmpfile("glove.6B.100d.word2vec.txt")
glove2word2vec(glove_file, word2vec_glove_file)

# %%
model = KeyedVectors.load_word2vec_format(word2vec_glove_file)

# %%
model.most_similar('banana')
# Out:
# [('coconut', 0.7097253799438477),
#  ('mango', 0.705482542514801),
#  ('bananas', 0.6887733936309814),
#  ('potato', 0.6629636287689209),
#  ('pineapple', 0.6534532308578491),
#  ('fruit', 0.6519855260848999),
#  ('peanut', 0.6420576572418213),
#  ('pecan', 0.6349173188209534),
#  ('cashew', 0.6294420957565308),
#  ('papaya', 0.6246591210365295)]

# %%
result = model.most_similar(positive=['woman', 'king'], negative=['man'])
print("{}: {:.4f}".format(*result[0]))
# Out:
# queen: 0.7699

# %% [markdown]
# ### 训练词向量

# %%
#https://blog.csdn.net/weixin_38235865/article/details/115578458
#glove安装失败 https://blog.csdn.net/weixin_41596463/article/details/106781674
#准备数据集
from __future__ import print_function
import argparse
import pprint
import gensim
from glove import Glove
from glove import Corpus
import pkuseg
#分词
pkuseg.test(r'不要等到毕业以后.txt', r'不要等到毕业以后分词.txt', model_name = "default", user_dict = "default", postag = False, nthread = 5)

# %%
#1.准备数据集
with open(r'不要等到毕业以后分词.txt','r',encoding='utf-8') as f:
    sentense = [line.replace('\n','').split(' ')  for line in f.readlines() if line.strip()!='']
#sentense = [['你','是','谁'],['我','是','中国人']]
corpus_model = Corpus()
corpus_model.fit(sentense, window=10)#10
#corpus_model.save('corpus.model')
print('Dict size: %s' % len(corpus_model.dictionary))
#Dict size: 2485
print('Collocations: %s' % corpus_model.matrix.nnz)
#Collocations: 71160

# 2.训练
glove = Glove(no_components=100, learning_rate=0.05)#no_components 维度，可以与word2vec一起使用。
glove.fit(corpus_model.matrix, epochs=10, no_threads=1, verbose=True)
glove.add_dictionary(corpus_model.dictionary)

#3.corpus模型保存与加载
corpus_model.save('corpus.model')
corpus_model = Corpus.load('corpus.model')

# %%
glove.dictionary
# Out:
# {'迄今': 0,
#  '最': 1,
#  '实用': 2,
#  '的': 3,
#  '大学生': 4,
#  '人生': 5,
#  '规划': 6,
#  '工具书': 7,
#  '。': 8,
#  '这是': 9,
#  '一': 10,
#  '本': 11,
#  '用心': 12,
#  '打磨': 13,
#  '书': 14,
#  '完全': 15,
#  '不同于': 16,
#  '那些': 17,
#  '东拼西凑': 18,
#  '指南': 19,
#  '；': 20,
#  '没有': 21,
#  '理论': 22,
#  '说教': 23,
#  '，': 24,
#  '只有': 25,
#  '苦口婆心': 26,
#  '地': 27,
#  '规劝': 28,
#  '57': 29,
#  '条': 30,
#  '成长': 31,
#  '建议': 32,
#  '、': 33,
#  '个': 34,
#  '实操': 35,
#  '训练': 36,
#  '10': 37,
#  '位': 38,
#  '同学': 39,
#  '精彩': 40,
#  '分享': 41,
#  '40': 42,
#  '好': 43,
#  '推荐': 44,
#  '如果': 45,
#  '你': 46,
#  '是': 47,
#  '新生': 48,
#  '害怕': 49,
#  '未来': 50,
#  '找': 51,
#  '不': 52,
#  '到': 53,
#  '出口': 54,
#  '三流': 55,
#  '大学': 56,
#  '冷门': 57,
#  '专业': 58,
#  '迷茫': 59,
#  '老生': 60,
#  '看完': 61,
#  '这': 62,
#  '本书': 63,
#  '将': 64,
#  '改变': 65,
#  '命运': 66,
#  '轨迹': 67,
#  '内容': 68,
#  '要不': 69,
#  '要': 70,
#  '勤工俭学': 71,
#  '？': 72,
#  '如何': 73,
#  '经营': 74,
#  '自己': 75,
#  '人脉': 76,
#  '考研': 77,
#  '还是': 78,
#  '就业': 79,
#  '牛人': 80,
#  '成功': 81,
#  '能': 82,
#  '复制': 83,
#  '吗': 84,
#  '创业': 85,
#  '值得': 86,
#  '鼓励': 87,
#  '去': 88,
#  '上班': 89,
#  '考': 90,
#  '公务员': 91,
#  '该书': 92,
#  '从': 93,
#  '入学': 94,
#  '后': 95,
#  '期间': 96,
#  '社会': 97,
#  '实践': 98,
#  '毕业': 99,
#  '求职': 100,
#  '各': 101,
#  '方面': 102,
#  '全面': 103,
#  '深入': 104,
#  '回答': 105,
#  '了': 106,
#  '困扰': 107,
#  '着': 108,
#  '当前': 109,
#  '系列': 110,
#  '问题': 111,
#  '无论': 112,
#  '二': 113,
#  '与其说': 114,
#  '帮助': 115,
#  '不如说': 116,
#  '告诉': 117,
#  '和': 118,
#  '组织': 119,
#  '整个': 120,
#  '四': 121,
#  '年': 122,
#  '作者': 123,
#  '简介': 124,
#  '张志': 125,
#  '微博': 126,
#  '@': 127,
#  '秋叶': 128,
#  '语录': 129,
#  '中国': 130,
#  '受': 131,
#  '欢迎': 132,
#  '与': 133,
#  '指导': 134,
#  '导师': 135,
#  '之一': 136,
#  '现': 137,
#  '为': 138,
#  '武汉': 139,
#  '工程': 140,
#  '教师': 141,
#  '上海': 142,
#  '卓弈': 143,
#  '企业': 144,
#  '管理': 145,
#  '咨询': 146,
#  '公司': 147,
#  '首席': 148,
#  '讲师': 149,
#  '大': 150,
#  '项目': 151,
#  '商务': 152,
#  '策划': 153,
#  '及': 154,
#  '网络': 155,
#  '营销': 156,
#  '传播': 157,
#  '顾问': 158,
#  '三栖': 159,
#  '职场': 160,
#  '人物': 161,
#  '著有': 162,
#  '《': 163,
#  '说服力': 164,
#  '让': 165,
#  'PPT': 166,
#  '会': 167,
#  '说话': 168,
#  '》': 169,
#  '电子版': 170,
#  '地址': 171,
#  '：': 172,
#  'http://auction': 173,
#  '1.': 174,
#  'paipai.com': 175,
#  '/': 176,
#  'AED7DD1E': 177,
#  '000000000401000036FD': 178,
#  '5653': 179,
#  '目录': 180,
#  '第一': 181,
#  '章': 182,
#  '职业': 183,
#  '才能': 184,
#  '我': 185,
#  '想': 186,
#  '换': 187,
#  '一个': 188,
#  '喜欢': 189,
#  '我们': 190,
#  '能够': 191,
#  '又': 192,
#  '通': 193,
#  '专': 194,
#  '培养': 195,
#  '种': 196,
#  '终身': 197,
#  '受益': 198,
#  '兴趣': 199,
#  '第二': 200,
#  '读书': 201,
#  '学习': 202,
#  '学会': 203,
#  '自学': 204,
#  '才': 205,
#  '算': 206,
#  '读': 207,
#  '过': 208,
#  '为什么': 209,
#  '有些': 210,
#  '人': 211,
#  '效率': 212,
#  '高': 213,
#  '写好': 214,
#  '论文': 215,
#  '帮': 216,
#  '建立': 217,
#  '思考': 218,
#  '框架': 219,
#  '写出': 220,
#  '篇': 221,
#  '长文章': 222,
#  '思路': 223,
#  '就': 224,
#  '模仿': 225,
#  '开始': 226,
#  '提': 227,
#  '具体': 228,
#  '多维': 229,
#  '角度': 230,
#  '一切': 231,
#  '信息': 232,
#  '中': 233,
#  '选书': 234,
#  '多': 235,
#  '提高': 236,
#  '竞争力': 237,
#  '第三': 238,
#  '社团': 239,
#  '该': 240,
#  '加入': 241,
#  '各种': 242,
#  '在': 243,
#  '里': 244,
#  '感觉': 245,
#  '学': 246,
#  '东西': 247,
#  '占据': 248,
#  '太': 249,
#  '时间': 250,
#  '怎么办': 251,
#  '也': 252,
#  '有': 253,
#  '许多': 254,
#  '公平': 255,
#  '！': 256,
#  '第四': 257,
#  '友情': 258,
#  '爱情': 259,
#  '应': 260,
#  '应该': 261,
#  '谈恋爱': 262,
#  '相处': 263,
#  '怎样': 264,
#  '交往': 265,
#  '容易': 266,
#  '变成': 267,
#  '第五': 268,
#  '选择': 269,
#  '好的': 270,
#  '方向': 271,
#  '工作': 272,
#  '家里': 273,
#  '出国': 274,
#  '留学': 275,
#  '意义': 276,
#  '第六': 277,
#  '了解': 278,
#  '面试': 279,
#  '单位': 280,
#  '写': 281,
#  '份': 282,
#  '简历': 283,
#  '名企': 284,
#  '实习生': 285,
#  '经历': 286,
#  '值钱': 287,
#  '考证': 288,
#  '对': 289,
#  '有用': 290,
#  '请': 291,
#  '学点': 292,
#  '礼仪': 293,
#  '签约': 294,
#  '以后': 295,
#  '反悔': 296,
#  '第七': 297,
#  '生活': 298,
#  '习惯': 299,
#  '控制': 300,
#  '击败': 301,
#  '拖延症': 302,
#  '专注力': 303,
#  '制定': 304,
#  '完成': 305,
#  '计划': 306,
#  '记账': 307,
#  '理财力': 308,
#  '留住': 309,
#  '好奇心': 310,
#  '观察力': 311,
#  '野蛮': 312,
#  '身体': 313,
#  '第八': 314,
#  '个人': 315,
#  '拥抱': 316,
#  '这个': 317,
#  '还': 318,
#  '信任': 319,
#  '钱': 320,
#  '做': 321,
#  '公益': 322,
#  '上': 323,
#  '看到': 324,
#  '不平': 325,
#  '事情': 326,
#  '合格': 327,
#  '公民': 328,
#  '独立': 329,
#  '第九': 330,
#  '天性': 331,
#  '信仰': 332,
#  '次': 333,
#  '背包客': 334,
#  '外表': 335,
#  '满意': 336,
#  '入党': 337,
#  '内心': 338,
#  '阴暗': 339,
#  '不是': 340,
#  '错': 341,
#  '底线': 342,
#  '很': 343,
#  '难': 344,
#  '第十': 345,
#  '反复': 346,
#  '每天': 347,
#  '不过': 348,
#  '重复': 349,
#  '画圆': 350,
#  '慢': 351,
#  '反而': 352,
#  '加速': 353,
#  '后记': 354,
#  '难以': 355,
#  '做出': 356,
#  '媒体': 357,
#  '评论': 358,
#  '大家': 359,
#  '看看': 360,
#  '老师': 361,
#  '并': 362,
#  '不只': 363,
#  '简单': 364,
#  '谈论': 365,
#  '而是': 366,
#  '把': 367,
#  '每': 368,
#  '都': 369,
#  '尽可能': 370,
#  '谈': 371,
#  '得': 372,
#  '透彻': 373,
#  '古典': 374,
#  '新': 375,
#  '精英': 376,
#  '总裁': 377,
#  '拆掉': 378,
#  '思维': 379,
#  '墙': 380,
#  '所': 381,
#  '选': 382,
#  '读者': 383,
#  '比较': 384,
#  '期待': 385,
#  '私藏': 386,
#  '时代': 387,
#  '年轻': 388,
#  '朋友': 389,
#  '需要': 390,
#  '声音': 391,
#  '袁岳': 392,
#  '零点': 393,
#  '研究': 394,
#  '集团': 395,
#  '董事长': 396,
#  '当': 397,
#  '校长': 398,
#  '受用': 399,
#  '打算': 400,
#  '它': 401,
#  '主要': 402,
#  '作为': 403,
#  '培训': 404,
#  '胡建波': 405,
#  '西安': 406,
#  '欧亚学院': 407,
#  '教授': 408,
#  '几乎': 409,
#  '每个': 410,
#  '走': 411,
#  '进': 412,
#  '年轻人': 413,
#  '奔跑': 414,
#  '欲望': 415,
#  '但': 416,
#  '很多': 417,
#  '苦于': 418,
#  '提供': 419,
#  '正确': 420,
#  '方法': 421,
#  '连': 422,
#  '近': 423,
#  '30年': 424,
#  '教龄': 425,
#  '老': 426,
#  '深': 427,
#  '感悟': 428,
#  '刘': 429,
#  '玉': 430,
#  '华中': 431,
#  '科技': 432,
#  '电信系': 433,
#  '点': 434,
#  '团队': 435,
#  '创始人': 436,
#  '覆盖': 437,
#  '各个': 438,
#  '唐红波': 439,
#  '辅导员': 440,
#  '线试': 441,
#  '部分': 442,
#  '章节': 443,
#  '那么': 444,
#  '2008年': 445,
#  '现在': 446,
#  '一直': 447,
#  '坚持': 448,
#  '用': 449,
#  '“': 450,
#  '”': 451,
#  '网名': 452,
#  '博客': 453,
#  '微信': 454,
#  '等': 455,
#  '新媒体': 456,
#  '回复': 457,
#  '来自': 458,
#  '全国': 459,
#  '其中': 460,
#  '每年': 461,
#  '被': 462,
#  '一遍遍': 463,
#  '问': 464,
#  '起': 465,
#  '比如': 466,
#  '听从': 467,
#  '父母': 468,
#  '安排': 469,
#  '报': 470,
#  '怎么': 471,
#  '分手': 472,
#  'Ta能': 473,
#  '主动': 474,
#  '追': 475,
#  '发现': 476,
#  '困难': 477,
#  '在于': 478,
#  '无法': 479,
#  '敢': 480,
#  '不断': 481,
#  '这样': 482,
#  '进入': 483,
#  '纠结': 484,
#  '花': 485,
#  '什么': 486,
#  '系统': 487,
#  '他们': 488,
#  '真正': 489,
#  '打开': 490,
#  '而': 491,
#  '盲目': 492,
#  '崇拜': 493,
#  '名': 494,
#  '一些': 495,
#  '行动': 496,
#  '标准': 497,
#  '答案': 498,
#  '建义': 499,
#  '未必': 500,
#  '适合': 501,
#  '最好': 502,
#  '对于': 503,
#  '只': 504,
#  '不够': 505,
#  '否则': 506,
#  '因为': 507,
#  '真实': 508,
#  '进展': 509,
#  '陷入': 510,
#  '现实': 511,
#  '更': 512,
#  '失望': 513,
#  '缺乏': 514,
#  '可': 515,
#  '方案': 516,
#  '必要': 517,
#  '只要': 518,
#  '你们': 519,
#  '尽早': 520,
#  '很快': 521,
#  '找到': 522,
#  '那': 523,
#  '路': 524,
#  '给': 525,
#  '且': 526,
#  '具有': 527,
#  '操作性': 528,
#  '这些': 529,
#  '不仅仅': 530,
#  '适用于': 531,
#  '将来': 532,
#  '起到': 533,
#  '作用': 534,
#  '鸡汤': 535,
#  '件': 536,
#  '知道': 537,
#  '多少': 538,
#  '爱': 539,
#  '看': 540,
#  '轻松': 541,
#  '或者': 542,
#  '努力': 543,
#  '书写': 544,
#  '接地气': 545,
#  '吧': 546,
#  '怕': 547,
#  '讨好人': 548,
#  '俏皮话': 549,
#  '见': 550,
#  '实效': 551,
#  '稍微': 552,
#  '一点': 553,
#  '同学们': 554,
#  '觉得': 555,
#  '起来': 556,
#  '累': 557,
#  '放弃': 558,
#  '泛泛': 559,
#  '一定': 560,
#  '使': 561,
#  '除非': 562,
#  '先': 563,
#  '进行': 564,
#  '有效': 565,
#  '然后': 566,
#  '采取': 567,
#  '反思': 568,
#  '成效': 569,
#  '所以': 570,
#  '定下': 571,
#  '非常': 572,
#  '挑战性': 573,
#  '任务': 574,
#  '受到': 575,
#  '刺激': 576,
#  '他': 577,
#  '但是': 578,
#  '切实': 579,
#  '一样': 580,
#  '技能': 581,
#  '障碍': 582,
#  '耐心': 583,
#  '认为': 584,
#  '愿意': 585,
#  '哪里': 586,
#  '入手': 587,
#  '围绕': 588,
#  '关心': 589,
#  '十': 590,
#  '话题': 591,
#  '展开': 592,
#  '希望': 593,
#  '动手': 594,
#  '依据': 595,
#  '参考': 596,
#  '对照': 597,
#  '实际': 598,
#  '情况': 599,
#  '练习': 600,
#  '记住': 601,
#  '现状': 602,
#  '经过': 603,
#  '2009年': 604,
#  '2月份': 605,
#  '认真': 606,
#  '之前': 607,
#  '10年': 608,
#  '依然': 609,
#  '停留': 610,
#  '套用': 611,
#  '模板': 612,
#  '阶段': 613,
#  '2010年': 614,
#  '却': 615,
#  '称为': 616,
#  '高手': 617,
#  '成为': 618,
#  '啊': 619,
#  '其实': 620,
#  '之间': 621,
#  '距离': 622,
#  '差': 623,
#  '结尾处': 624,
#  '普通': 625,
#  '故事': 626,
#  '可以': 627,
#  '启发': 628,
#  '进步': 629,
#  '一点点': 630,
#  '为了': 631,
#  '大学生们': 632,
#  '专门': 633,
#  '开设': 634,
#  '公众': 635,
#  '账户': 636,
#  '秋夜': 637,
#  '青语': 638,
#  '出版': 639,
#  '前': 640,
#  '已经': 641,
#  '超过': 642,
#  '10000': 643,
#  '通过': 644,
#  '向': 645,
#  '提问': 646,
#  '都会': 647,
#  '尽力': 648,
#  '一一': 649,
#  '解答': 650,
#  '有趣': 651,
#  '玩法': 652,
#  '拿出': 653,
#  '手机': 654,
#  '扫': 655,
#  '二维码': 656,
#  '关注': 657,
#  '文字': 658,
#  '胡适': 659,
#  '两': 660,
#  '字': 661,
#  '1932年': 662,
#  '赠与': 663,
#  '今年': 664,
#  '毕业生': 665,
#  '文章': 666,
#  '处': 667,
#  '设置': 668,
#  '关键词': 669,
#  '这里': 670,
#  '统一': 671,
#  '指': 672,
#  '（': 673,
#  '直接': 674,
#  '搜号码': 675,
#  '中搜': 676,
#  '）': 677,
#  '创新': 678,
#  '之': 679,
#  '设计': 680,
#  '题目': 681,
#  '心得': 682,
#  '形式': 683,
#  '手绘': 684,
#  '等等': 685,
#  '发': 686,
#  '爱特': 687,
#  '转发': 688,
#  '加上': 689,
#  '标签': 690,
#  '以便': 691,
#  '于': 692,
#  '搜索': 693,
#  '一起': 694,
#  '同伴': 695,
#  '世界': 696,
#  '扇': 697,
#  '门': 698,
#  '[': 699,
#  '试读': 700,
#  ']': 701,
#  '最近': 702,
#  '几': 703,
#  '流行': 704,
#  '电视': 705,
#  '达人秀': 706,
#  '比赛': 707,
#  '歌手': 708,
#  '类': 709,
#  '节目': 710,
#  '心里': 711,
#  '梦想': 712,
#  '学校': 713,
#  '浑浑噩噩': 714,
#  '过日子': 715,
#  '理由': 716,
#  '目前': 717,
#  '感': 718,
#  '说': 719,
#  '假如': 720,
#  '肯定': 721,
#  '像': 722,
#  '达人们': 723,
#  '听到': 724,
#  '学生': 725,
#  '以': 726,
#  '为由': 727,
#  '好好': 728,
#  '荒废': 729,
#  '学业': 730,
#  '虚度': 731,
#  '青春': 732,
#  '深感': 733,
#  '痛惜': 734,
#  '无情': 735,
#  '打击': 736,
#  '相信': 737,
#  '感动': 738,
#  '落泪': 739,
#  '参赛': 740,
#  '选手': 741,
#  '哪个': 742,
#  '一帆风顺': 743,
#  '之所以': 744,
#  '赚到': 745,
#  '眼泪': 746,
#  '面前': 747,
#  '一味': 748,
#  '抱怨': 749,
#  '不好': 750,
#  '懒散': 751,
#  '求': 752,
#  '进取': 753,
#  '借口': 754,
#  '只能': 755,
#  '真的': 756,
#  '走到': 757,
#  '生存': 758,
#  '一技之长': 759,
#  '等于': 760,
#  '爱好': 761,
#  '毕业证': 762,
#  '所谓': 763,
#  '含义': 764,
#  '就是': 765,
#  '不管': 766,
#  '是否': 767,
#  '必须': 768,
#  '大量': 769,
#  '艰苦': 770,
#  '靠': 771,
#  '业': 772,
#  '99%': 773,
#  '奢望': 774,
#  '拥有': 775,
#  '立足': 776,
#  '个性': 777,
#  '发挥': 778,
#  '空间': 779,
#  '机会': 780,
#  '还有': 781,
#  '强调': 782,
#  '充分': 783,
#  '优势': 784,
#  '特别': 785,
#  '天赋': 786,
#  '尽快': 787,
#  '机械': 788,
#  '广告': 789,
#  '文案': 790,
#  '制作': 791,
#  '自信': 792,
#  '一流': 793,
#  '领域': 794,
#  '平庸': 795,
#  '正是': 796,
#  '谋得': 797,
#  '教职': 798,
#  '慢慢': 799,
#  '发展': 800,
#  '好比学': 801,
#  '做饭': 802,
#  '肯': 803,
#  '顶尖级': 804,
#  '大厨': 805,
#  '厨艺': 806,
#  '天分': 807,
#  '除了': 808,
#  '个别': 809,
#  '当今': 810,
#  '里面': 811,
#  '功课': 812,
#  '要求': 813,
#  '多么': 814,
#  '智商': 815,
#  '也许': 816,
#  '一下': 817,
#  '根本': 818,
#  '适应': 819,
#  '掌握': 820,
#  '绝大部分': 821,
#  '天才': 822,
#  '特殊': 823,
#  '修炼': 824,
#  '成器': 825,
#  '勤奋': 826,
#  '+': 827,
#  '打败': 828,
#  '武器': 829,
#  '担心': 830,
#  '调换': 831,
#  '客观': 832,
#  '存在': 833,
#  '提醒': 834,
#  '需': 835,
#  '冷静': 836,
#  '三': 837,
#  '哪': 838,
#  '人才': 839,
#  '当然': 840,
#  '强迫': 841,
#  '没': 842,
#  '只是': 843,
#  '至少': 844,
#  '说出': 845,
#  '什么的': 846,
#  '哪些': 847,
#  '行业': 848,
#  '岗位': 849,
#  '一无所知': 850,
#  '显得': 851,
#  '苍白': 852,
#  '试试': 853,
#  '能否': 854,
#  '出': 855,
#  '热情': 856,
#  '任何': 857,
#  '做到': 858,
#  '精深': 859,
#  '愁': 860,
#  '缺': 861,
#  '成就感': 862,
#  '态度': 863,
#  '事': 864,
#  '自然': 865,
#  '拿': 866,
#  '回报': 867,
#  '意味着': 868,
#  '竞争': 869,
#  '对手': 870,
#  '少': 871,
#  '热门': 872,
#  '考虑': 873,
#  '利用': 874,
#  '家庭': 875,
#  '资源': 876,
#  '背景': 877,
#  '相当': 878,
#  '技术': 879,
#  '含量': 880,
#  '总': 881,
#  '吃饭': 882,
#  '最后': 883,
#  '段': 884,
#  '罗振宇': 885,
#  '讲': 886,
#  '视频': 887,
#  '罗辑': 888,
#  '——': 889,
#  '夹缝': 890,
#  '80后': 891,
#  '收获': 892,
#  '绘制': 893,
#  '所在': 894,
#  '流程图': 895,
#  '大都': 896,
#  '调整': 897,
#  '不同': 898,
#  '规定': 899,
#  '明白': 900,
#  '决定': 901,
#  '转': 902,
#  '弄': 903,
#  '清楚': 904,
#  '相关': 905,
#  '流程': 906,
#  '启动': 907,
#  '尝试': 908,
#  '画出': 909,
#  '图': 910,
#  '2': 911,
#  '整体': 912,
#  '准确': 913,
#  '判断': 914,
#  '关键': 915,
#  '环节': 916,
#  '不可': 917,
#  '预测': 918,
#  '挫折': 919,
#  '做好': 920,
#  '足够': 921,
#  '心理': 922,
#  '准备': 923,
#  '衔接': 924,
#  '顺序': 925,
#  '过程': 926,
#  '传递': 927,
#  '如': 928,
#  '负责人': 929,
#  '谁': 930,
#  '满足': 931,
#  '条件': 932,
#  '下': 933,
#  '无': 934,
#  '资金': 935,
#  '或': 936,
#  '其他': 937,
#  '……': 938}

# %%
# 指定词条词向量 
glove.word_vectors[glove.dictionary['你']]
# Out:
# array([ 0.00136432,  0.00451072,  0.00255695, -0.00288016,  0.00086107,
#        -0.00859637,  0.00186229, -0.00460266, -0.00023735, -0.00412373,
#         0.00337095, -0.00084839,  0.00291818, -0.00182306,  0.00587481,
#        -0.00299768, -0.00161082, -0.00650886, -0.00155389, -0.00098691,
#        -0.00312313,  0.00598255,  0.01031912,  0.00542368,  0.00509461,
#        -0.00067459,  0.00864356, -0.00391939, -0.00077407,  0.00320261,
#         0.00677831, -0.00484086,  0.0028462 , -0.0080345 , -0.01011046,
#        -0.00056112, -0.01274233,  0.00281066,  0.0029566 ,  0.00304075,
#        -0.00781528,  0.0065882 ,  0.00489784, -0.00536406,  0.00291707,
#         0.00331725, -0.00503833,  0.00073955, -0.00111529, -0.00289287,
#        -0.00639859, -0.00315403,  0.00467362, -0.00637617,  0.00350139,
#         0.00225475,  0.00463465, -0.00872295, -0.00202497, -0.00294925,
#        -0.00733676,  0.00759704,  0.00172933, -0.00451997, -0.00361714,
#         0.00390157, -0.00219644,  0.00549355,  0.00234482,  0.00420256,
#        -0.00010708,  0.00417842,  0.00722365,  0.00903018, -0.00023202,
#         0.00556976,  0.00424416,  0.00412863,  0.00517744, -0.00757381,
#        -0.00872792, -0.00290013,  0.00542473,  0.00144621,  0.00727905,
#        -0.00114519, -0.00399584,  0.00161757,  0.00550445,  0.00367767,
#         0.01266088,  0.00329414,  0.0010506 , -0.00506546, -0.00264134,
#        -0.00297867, -0.00877398, -0.00804135, -0.00130016,  0.00635221])

# %%
# 相似词
glove.most_similar('专业', number = 10)
# Out:
# [('的', 0.9102666956529802),
#  ('，', 0.9044421481990059),
#  ('是', 0.8020140578163827),
#  ('你', 0.7740375217006199),
#  ('。', 0.7234846547183538),
#  ('我', 0.6427754536281617),
#  ('不', 0.5891415863985422),
#  ('自己', 0.5325897063346139),
#  ('也', 0.5280655146944074)]

# %%
# 全部词向量矩阵
#glove.word_vectors

#语料协同矩阵 corpus coocurrence matrix
#corpus_model.matrix.todense().tolist()
